# %% [markdown]
# # This script contains the following points:¶
# 1. Create data to experiment on
# 2. Convert the dictionaries into dataframes
# 3. Concatenate the dataframes
# 4. Joining the dataframes
# 5. Merging the dataframes

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 1. Create data to experiment on

# %%
# Define a dictionary containing January 2020 data
data1 = {'customer_id':['6732', '767', '890', '635'],
    'month':['Jan-20', 'Jan-20', 'Jan-20', 'Jan-20'],
    'purchased_meat':[0, 13, 3, 4],
    'purchased_alcohol':[1, 2, 10, 0],
    'purchased_snacks':[10, 5, 1, 7]}

# %%
# Define a dictionary containing February 2020 data
data2 = {'customer_id':['6732', '767', '890', '635'],
    'month':['Feb-20', 'Feb-20', 'Feb-20', 'Feb-20'],
    'purchased_meat':[0, 10, 5, 3],
    'purchased_alcohol':[2, 4, 14, 0],
    'purchased_snacks':[15, 3, 2, 6]}

# %% [markdown]
# ## 2. convert the dictionaries into dataframe

# %%
# Convert the dictionary into dataframe
df = pd.DataFrame(data1,index=[0, 1, 2, 3])
df_1 = pd.DataFrame(data2,index=[0, 1, 2, 3])

# %%
df
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7

# %%
df_1
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Feb-20               0                  2                15
# 1         767  Feb-20              10                  4                 3
# 2         890  Feb-20               5                 14                 2
# 3         635  Feb-20               3                  0                 6

# %% [markdown]
# ## 3. Concatenate the dataframes

# %%
# concatenating the dataframes
# framing the dataframes: 
frames = [df, df_1]

# %%
# concatenationg the frames:
df_concat = pd.concat(frames)

# %%
df_concat
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
# 0        6732  Feb-20               0                  2                15
# 1         767  Feb-20              10                  4                 3
# 2         890  Feb-20               5                 14                 2
# 3         635  Feb-20               3                  0                 6

# %%
# concatenationg dataframes side by side
df_concat = pd.concat(frames, axis = 1)

# %%
df_concat
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
#
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Feb-20               0                  2                15
# 1         767  Feb-20              10                  4                 3
# 2         890  Feb-20               5                 14                 2
# 3         635  Feb-20               3                  0                 6

# %% [markdown]
# ## 4. Joining Dataframes
# df.join()

# %% [markdown]
# ## 5. Merging Dataframes

# %%
# Merging dataframes: identifier: customer_id 
df_merged = df.merge(df_1, on = 'customer_id')

# %%
df_merged
# Out:
#   customer_id month_x  purchased_meat_x  purchased_alcohol_x  \
# 0        6732  Jan-20                 0                    1
# 1         767  Jan-20                13                    2
# 2         890  Jan-20                 3                   10
# 3         635  Jan-20                 4                    0
#
#    purchased_snacks_x month_y  purchased_meat_y  purchased_alcohol_y  \
# 0                  10  Feb-20                 0                    2
# 1                   5  Feb-20                10                    4
# 2                   1  Feb-20                 5                   14
# 3                   7  Feb-20                 3                    0
#
#    purchased_snacks_y
# 0                  15
# 1                   3
# 2                   2
# 3                   6

# %%
# Merging dataframes: identifier: customer_id and month
df_merged = df.merge(df_1, on = ['customer_id','month'])

# %%
df_merged
# Out:
# Empty DataFrame
# Columns: [customer_id_x, month, purchased_meat_x, purchased_alcohol_x, purchased_snacks_x, customer_id_y, purchased_meat_y, purchased_alcohol_y, purchased_snacks_y]
# Index: []

# %%
# check if dataframes match
df_merged = df.merge(df_1, on = ['customer_id'], indicator = True)

# %%
df_merged
# Out:
#   customer_id month_x  purchased_meat_x  purchased_alcohol_x  \
# 0        6732  Jan-20                 0                    1
# 1         767  Jan-20                13                    2
# 2         890  Jan-20                 3                   10
# 3         635  Jan-20                 4                    0
#
#    purchased_snacks_x month_y  purchased_meat_y  purchased_alcohol_y  \
# 0                  10  Feb-20                 0                    2
# 1                   5  Feb-20                10                    4
# 2                   1  Feb-20                 5                   14
# 3                   7  Feb-20                 3                    0
#
#    purchased_snacks_y _merge
# 0                  15   both
# 1                   3   both
# 2                   2   both
# 3                   6   both

# %%
df_merged['_merge'].value_counts()
# Out:
# both          4
# left_only     0
# right_only    0
# Name: _merge, dtype: int64

# %%
# Test merge without overwriting
pd.merge(df,df_1, on = ['customer_id'], indicator = True)
# Out:
#   customer_id month_x  purchased_meat_x  purchased_alcohol_x  \
# 0        6732  Jan-20                 0                    1
# 1         767  Jan-20                13                    2
# 2         890  Jan-20                 3                   10
# 3         635  Jan-20                 4                    0
#
#    purchased_snacks_x month_y  purchased_meat_y  purchased_alcohol_y  \
# 0                  10  Feb-20                 0                    2
# 1                   5  Feb-20                10                    4
# 2                   1  Feb-20                 5                   14
# 3                   7  Feb-20                 3                    0
#
#    purchased_snacks_y _merge
# 0                  15   both
# 1                   3   both
# 2                   2   both
# 3                   6   both
